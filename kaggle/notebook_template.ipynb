# %% [markdown]
# # Dylumo Training on Kaggle
#
# This notebook trains the Dylumo image-to-music model using Kaggle's GPU.
#
# **Instructions:**
# 1. Enable GPU in notebook settings
# 2. Attach your dataset (with image_features.npy and music_features.npy)
# 3. Run all cells

# %%
# Install dependencies
# !pip install faiss-cpu clip-by-openai

# %%
# Import the training script
# Option 1: If you uploaded kaggle_train.py to your dataset
import sys
sys.path.append('/kaggle/input/dylumo-data')  # Update dataset name
from kaggle_train import main

# Option 2: Or copy the entire kaggle_train.py code here
# Then just call: main()

# %%
# Run training
# Make sure your dataset is attached and paths are correct
main()
